# %% [markdown]
# Some ideas to explore:
#
# > * Various relationships between movie budget, revenues, genres, ratings, release date, production company, and language.
# > * How have budgets and revenues for movies changed over time?
# > * Are there relationships between the budget for a movie and how much revenue it generates?
# > * Do certain genres of movies generate more revenue than others? Higher ratings than others?
# > * Does runtime impact budget, revenue, or rating?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ast import literal_eval
import seaborn as sns

# %%
movies_meta = pd.read_csv('./archive/movies_metadata.csv')
movies_meta.head(2)
# Out:
# /Users/coxem/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
movies_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
movies_meta = movies_meta[['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video', 'vote_average', 'vote_count']]

# %%
movies_meta.head(2)
# Out:
#    adult    budget                                             genres    id  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   862
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  8844
#
#      imdb_id original_language  \
# 0  tt0114709                en
# 1  tt0113497                en
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status      title  video  vote_average  vote_count
# 0  Released  Toy Story  False           7.7      5415.0
# 1  Released    Jumanji  False           6.9      2413.0

# %%
movies_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45466 non-null  object
#  1   budget                45466 non-null  object
#  2   genres                45466 non-null  object
#  3   id                    45466 non-null  object
#  4   imdb_id               45449 non-null  object
#  5   original_language     45455 non-null  object
#  6   production_companies  45463 non-null  object
#  7   production_countries  45463 non-null  object
#  8   release_date          45379 non-null  object
#  9   revenue               45460 non-null  float64
#  10  runtime               45203 non-null  float64
#  11  spoken_languages      45460 non-null  object
#  12  status                45379 non-null  object
#  13  title                 45460 non-null  object
#  14  video                 45460 non-null  object
#  15  vote_average          45460 non-null  float64
#  16  vote_count            45460 non-null  float64
# dtypes: float64(4), object(13)
# memory usage: 5.9+ MB

# %%
movies_meta['genres'].describe()
# Out:
# count                             45466
# unique                             4069
# top       [{'id': 18, 'name': 'Drama'}]
# freq                               5000
# Name: genres, dtype: object

# %%
genres_df = pd.DataFrame(movies_meta['genres'])
genres_df
# Out:
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
# [45466 rows x 1 columns]

# %%
genres_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genres  45466 non-null  object
# dtypes: object(1)
# memory usage: 355.3+ KB

# %%
#genres_df.genres = genres_df.genres.apply(lambda x: literal_eval(x))
#genres_df.genres

# %%
def literal_return(val):
    try:
        return literal_eval(val)
    except (ValueError, SyntaxError) as e:
        return val

def str_to_list_of_dicts(df, column_name):
    df[column_name] = df[column_name].apply(literal_return)
    return df[column_name]

def genres_cleaner(list_of_dicts):
    if isinstance(list_of_dicts, list):
        return [d['name'] for d in list_of_dicts]
    #Return empty list in case of missing/malformed data
    return []

def countries_cleaner(list_of_dicts):
    if isinstance(list_of_dicts, list):
        return [d['iso_3166_1'] for d in list_of_dicts]
    return []

def language_cleaner(list_of_dicts):
    if isinstance(list_of_dicts, list):
        return [d['iso_639_1'] for d in list_of_dicts]
    return []

# %%
genres_lists = str_to_list_of_dicts(df = genres_df, column_name = 'genres').map(genres_cleaner)
genres_lists
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45466, dtype: object

# %%
genres_counts = genres_lists.explode().value_counts()
genres_counts
# Out:
# Drama                                    20265
# Comedy                                   13182
# Thriller                                  7624
# Romance                                   6735
# Action                                    6596
# Horror                                    4673
# Crime                                     4307
# Documentary                               3932
# Adventure                                 3496
# Science Fiction                           3049
# Family                                    2770
# Mystery                                   2467
# Fantasy                                   2313
# Animation                                 1935
# Foreign                                   1622
# Music                                     1598
# History                                   1398
# War                                       1323
# Western                                   1042
# TV Movie                                   767
# Carousel Productions                         1
# Odyssey Media                                1
# BROSTA TV                                    1
# Pulser Productions                           1
# Telescene Film Group Productions             1
# Mardock Scramble Production Committee        1
# Vision View Entertainment                    1
# Rogue State                                  1
# GoHands                                      1
# The Cartel                                   1
# Sentai Filmworks                             1
# Aniplex                                      1
# Name: genres, dtype: int64

# %%
genres_counts_df = genres_counts.to_frame('counts').reset_index()
genres_counts_df = genres_counts_df.rename(columns = {'index': 'genre'})
genres_counts_df
# Out:
#                                     genre  counts
# 0                                   Drama   20265
# 1                                  Comedy   13182
# 2                                Thriller    7624
# 3                                 Romance    6735
# 4                                  Action    6596
# 5                                  Horror    4673
# 6                                   Crime    4307
# 7                             Documentary    3932
# 8                               Adventure    3496
# 9                         Science Fiction    3049
# 10                                 Family    2770
# 11                                Mystery    2467
# 12                                Fantasy    2313
# 13                              Animation    1935
# 14                                Foreign    1622
# 15                                  Music    1598
# 16                                History    1398
# 17                                    War    1323
# 18                                Western    1042
# 19                               TV Movie     767
# 20                   Carousel Productions       1
# 21                          Odyssey Media       1
# 22                              BROSTA TV       1
# 23                     Pulser Productions       1
# 24       Telescene Film Group Productions       1
# 25  Mardock Scramble Production Committee       1
# 26              Vision View Entertainment       1
# 27                            Rogue State       1
# 28                                GoHands       1
# 29                             The Cartel       1
# 30                       Sentai Filmworks       1
# 31                                Aniplex       1

# %%
genres_counts_df = genres_counts_df[genres_counts_df.counts > 1]
genres_counts_df
# Out:
#               genre  counts
# 0             Drama   20265
# 1            Comedy   13182
# 2          Thriller    7624
# 3           Romance    6735
# 4            Action    6596
# 5            Horror    4673
# 6             Crime    4307
# 7       Documentary    3932
# 8         Adventure    3496
# 9   Science Fiction    3049
# 10           Family    2770
# 11          Mystery    2467
# 12          Fantasy    2313
# 13        Animation    1935
# 14          Foreign    1622
# 15            Music    1598
# 16          History    1398
# 17              War    1323
# 18          Western    1042
# 19         TV Movie     767

# %%
movies_meta['genres'] = genres_lists
movies_meta.head()
# Out:
#    adult    budget                        genres     id    imdb_id  \
# 0  False  30000000   [Animation, Comedy, Family]    862  tt0114709
# 1  False  65000000  [Adventure, Fantasy, Family]   8844  tt0113497
# 2  False         0             [Romance, Comedy]  15602  tt0113228
# 3  False  16000000      [Comedy, Drama, Romance]  31357  tt0114885
# 4  False         0                      [Comedy]  11862  tt0113041
#
#   original_language                               production_companies  \
# 0                en     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1                en  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2                en  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3                en  [{'name': 'Twentieth Century Fox Film Corporat...
# 4                en  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                        title  video  vote_average  vote_count
# 0  Released                    Toy Story  False           7.7      5415.0
# 1  Released                      Jumanji  False           6.9      2413.0
# 2  Released             Grumpier Old Men  False           6.5        92.0
# 3  Released            Waiting to Exhale  False           6.1        34.0
# 4  Released  Father of the Bride Part II  False           5.7       173.0

# %%
#fig, ax = plt.subplots(figsize = (18, 8))
#x_data = genres_counts_df['genre']
#y_data = genres_counts_df['counts']

#ax.bar(x_data, y_data)

#ax.set_xlabel('Genre', fontsize = 20)
#ax.set_xticklabels(x_data, rotation = 45, fontsize = 20)
#ax.set_ylabel('# of Movies', fontsize = 20)
#ax.set_title('Counts of Movies by Genre', fontsize = 24)

#fig.tight_layout()

# %%
x_data = genres_counts_df['counts']
y_data = genres_counts_df['genre']
y = np.arange(len(y_data))
x = np.linspace(500, 20500, 21, dtype='int')


fig, ax = plt.subplots(figsize=(18,10))
ax.barh(y_data, x_data)
ax.invert_yaxis()
ax.set_yticks(y)
ax.set_xticks(x)
ax.set_xticklabels(x, fontsize = 18, rotation = 45)
ax.set_yticklabels(y_data, fontsize = 18)
ax.xaxis.grid(True)
ax.set_xlabel('# of Movies', fontsize = 24)
ax.set_title('Counts of Movies by Genre', fontsize = 24)
fig.tight_layout()

# %%
genres_list = genres_counts_df['genre'].tolist()
genres_list
# Out:
# ['Drama',
#  'Comedy',
#  'Thriller',
#  'Romance',
#  'Action',
#  'Horror',
#  'Crime',
#  'Documentary',
#  'Adventure',
#  'Science Fiction',
#  'Family',
#  'Mystery',
#  'Fantasy',
#  'Animation',
#  'Foreign',
#  'Music',
#  'History',
#  'War',
#  'Western',
#  'TV Movie']

# %%
def create_bool_columns(df, column_name, list_of_columns):
    for column in list_of_columns:
        df[column] = df[column_name].apply(lambda x: column in x)

# %%
create_bool_columns(df = movies_meta, column_name = 'genres', list_of_columns = genres_list)

# %%
movies_meta.head()
# Out:
#    adult    budget                        genres     id    imdb_id  \
# 0  False  30000000   [Animation, Comedy, Family]    862  tt0114709
# 1  False  65000000  [Adventure, Fantasy, Family]   8844  tt0113497
# 2  False         0             [Romance, Comedy]  15602  tt0113228
# 3  False  16000000      [Comedy, Drama, Romance]  31357  tt0114885
# 4  False         0                      [Comedy]  11862  tt0113041
#
#   original_language                               production_companies  \
# 0                en     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1                en  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2                en  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3                en  [{'name': 'Twentieth Century Fox Film Corporat...
# 4                en  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  ...  Family Mystery Fantasy Animation Foreign  Music  History  \
# 0  373554033.0  ...    True   False   False      True   False  False    False
# 1  262797249.0  ...    True   False    True     False   False  False    False
# 2          0.0  ...   False   False   False     False   False  False    False
# 3   81452156.0  ...   False   False   False     False   False  False    False
# 4   76578911.0  ...   False   False   False     False   False  False    False
#
#      War  Western  TV Movie
# 0  False    False     False
# 1  False    False     False
# 2  False    False     False
# 3  False    False     False
# 4  False    False     False
#
# [5 rows x 37 columns]

# %%
def make_genre_specific_df(df, genre):
    return df[df[genre] == True]

# %%
drama = make_genre_specific_df(movies_meta, 'Drama')
comedy = make_genre_specific_df(movies_meta, 'Comedy')
thriller = make_genre_specific_df(movies_meta, 'Thriller')
romance = make_genre_specific_df(movies_meta, 'Romance')
action = make_genre_specific_df(movies_meta, 'Action')
horror = make_genre_specific_df(movies_meta, 'Horror')
crime = make_genre_specific_df(movies_meta, 'Crime')
documentary = make_genre_specific_df(movies_meta, 'Documentary')
adventure = make_genre_specific_df(movies_meta, 'Adventure')
science_fiction = make_genre_specific_df(movies_meta, 'Science Fiction')
family = make_genre_specific_df(movies_meta, 'Family')
mystery = make_genre_specific_df(movies_meta, 'Mystery')
fantasy = make_genre_specific_df(movies_meta, 'Fantasy')
animation = make_genre_specific_df(movies_meta, 'Animation')
foreign = make_genre_specific_df(movies_meta, 'Foreign')
music = make_genre_specific_df(movies_meta, 'Music')
history = make_genre_specific_df(movies_meta, 'History')
war = make_genre_specific_df(movies_meta, 'War')
western = make_genre_specific_df(movies_meta, 'Western')
tv_movie = make_genre_specific_df(movies_meta, 'TV Movie')

# %%
drama.head()
# Out:
#     adult    budget                              genres     id    imdb_id  \
# 3   False  16000000            [Comedy, Drama, Romance]  31357  tt0114885
# 5   False  60000000    [Action, Crime, Drama, Thriller]    949  tt0113277
# 7   False         0  [Action, Adventure, Drama, Family]  45325  tt0112302
# 10  False  62000000            [Comedy, Drama, Romance]   9087  tt0112346
# 13  False  44000000                    [History, Drama]  10858  tt0113987
#
#    original_language                               production_companies  \
# 3                 en  [{'name': 'Twentieth Century Fox Film Corporat...
# 5                 en  [{'name': 'Regency Enterprises', 'id': 508}, {...
# 7                 en        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 10                en  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 13                en  [{'name': 'Hollywood Pictures', 'id': 915}, {'...
#
#                                  production_countries release_date  \
# 3   [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 5   [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 7   [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 10  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-11-17
# 13  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
#
#         revenue  ...  Family Mystery Fantasy Animation Foreign  Music  \
# 3    81452156.0  ...   False   False   False     False   False  False
# 5   187436818.0  ...   False   False   False     False   False  False
# 7           0.0  ...    True   False   False     False   False  False
# 10  107879496.0  ...   False   False   False     False   False  False
# 13   13681765.0  ...   False   False   False     False   False  False
#
#     History    War  Western  TV Movie
# 3     False  False    False     False
# 5     False  False    False     False
# 7     False  False    False     False
# 10    False  False    False     False
# 13     True  False    False     False
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Repeat cleaning process for other columns

# %%
prod_companies_df = pd.DataFrame(movies_meta['production_companies'])
prod_countries_df = pd.DataFrame(movies_meta['production_countries'])
spoken_language_df = pd.DataFrame(movies_meta['spoken_languages'])

# %%
prod_companies_df
# Out:
#                                     production_companies
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
# [45466 rows x 1 columns]

# %%
prod_companies_df['production_companies'][0]
# Out:
# "[{'name': 'Pixar Animation Studios', 'id': 3}]"

# %%
prod_companies_lists = str_to_list_of_dicts(df = prod_companies_df, column_name = 'production_companies').map(genres_cleaner)
prod_companies_lists
# Out:
# 0                                [Pixar Animation Studios]
# 1        [TriStar Pictures, Teitler Film, Interscope Co...
# 2                           [Warner Bros., Lancaster Gate]
# 3                 [Twentieth Century Fox Film Corporation]
# 4             [Sandollar Productions, Touchstone Pictures]
#                                ...
# 45461                                                   []
# 45462                                        [Sine Olivia]
# 45463                            [American World Pictures]
# 45464                                          [Yermoliev]
# 45465                                                   []
# Name: production_companies, Length: 45466, dtype: object

# %%
movies_meta['production_companies'] = prod_companies_lists
movies_meta.head()
# Out:
#    adult    budget                        genres     id    imdb_id  \
# 0  False  30000000   [Animation, Comedy, Family]    862  tt0114709
# 1  False  65000000  [Adventure, Fantasy, Family]   8844  tt0113497
# 2  False         0             [Romance, Comedy]  15602  tt0113228
# 3  False  16000000      [Comedy, Drama, Romance]  31357  tt0114885
# 4  False         0                      [Comedy]  11862  tt0113041
#
#   original_language                               production_companies  \
# 0                en                          [Pixar Animation Studios]
# 1                en  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                en                     [Warner Bros., Lancaster Gate]
# 3                en           [Twentieth Century Fox Film Corporation]
# 4                en       [Sandollar Productions, Touchstone Pictures]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  ...  Family Mystery Fantasy Animation Foreign  Music  History  \
# 0  373554033.0  ...    True   False   False      True   False  False    False
# 1  262797249.0  ...    True   False    True     False   False  False    False
# 2          0.0  ...   False   False   False     False   False  False    False
# 3   81452156.0  ...   False   False   False     False   False  False    False
# 4   76578911.0  ...   False   False   False     False   False  False    False
#
#      War  Western  TV Movie
# 0  False    False     False
# 1  False    False     False
# 2  False    False     False
# 3  False    False     False
# 4  False    False     False
#
# [5 rows x 37 columns]

# %%
prod_countries_df.head()
# Out:
#                                 production_countries
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...

# %%
prod_countries_df['production_countries'][0]
# Out:
# "[{'iso_3166_1': 'US', 'name': 'United States of America'}]"

# %%
prod_countries_lists = str_to_list_of_dicts(df = prod_countries_df, column_name = 'production_countries').map(genres_cleaner)
prod_countries_lists
# Out:
# 0        [United States of America]
# 1        [United States of America]
# 2        [United States of America]
# 3        [United States of America]
# 4        [United States of America]
#                     ...
# 45461                        [Iran]
# 45462                 [Philippines]
# 45463    [United States of America]
# 45464                      [Russia]
# 45465              [United Kingdom]
# Name: production_countries, Length: 45466, dtype: object

# %%
prod_countries_df['production_countries'][0]
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
prod_countries_df['country_iso'] = prod_countries_df['production_countries'].map(countries_cleaner)
prod_countries_df
# Out:
#                                     production_countries country_iso
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...        [US]
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...        [US]
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...        [US]
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...        [US]
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...        [US]
# ...                                                  ...         ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]        [IR]
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]        [PH]
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...        [US]
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]        [RU]
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]        [GB]
#
# [45466 rows x 2 columns]

# %%
prod_countries_df['production_countries'] = prod_countries_lists

# %%
prod_countries_df
# Out:
#              production_countries country_iso
# 0      [United States of America]        [US]
# 1      [United States of America]        [US]
# 2      [United States of America]        [US]
# 3      [United States of America]        [US]
# 4      [United States of America]        [US]
# ...                           ...         ...
# 45461                      [Iran]        [IR]
# 45462               [Philippines]        [PH]
# 45463  [United States of America]        [US]
# 45464                    [Russia]        [RU]
# 45465            [United Kingdom]        [GB]
#
# [45466 rows x 2 columns]

# %%
movies_meta['production_countries'] = prod_countries_lists
movies_meta['production_country_iso'] = prod_countries_df['country_iso']
movies_meta.head()
# Out:
#    adult    budget                        genres     id    imdb_id  \
# 0  False  30000000   [Animation, Comedy, Family]    862  tt0114709
# 1  False  65000000  [Adventure, Fantasy, Family]   8844  tt0113497
# 2  False         0             [Romance, Comedy]  15602  tt0113228
# 3  False  16000000      [Comedy, Drama, Romance]  31357  tt0114885
# 4  False         0                      [Comedy]  11862  tt0113041
#
#   original_language                               production_companies  \
# 0                en                          [Pixar Animation Studios]
# 1                en  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                en                     [Warner Bros., Lancaster Gate]
# 3                en           [Twentieth Century Fox Film Corporation]
# 4                en       [Sandollar Productions, Touchstone Pictures]
#
#          production_countries release_date      revenue  ...  Mystery Fantasy  \
# 0  [United States of America]   1995-10-30  373554033.0  ...    False   False
# 1  [United States of America]   1995-12-15  262797249.0  ...    False    True
# 2  [United States of America]   1995-12-22          0.0  ...    False   False
# 3  [United States of America]   1995-12-22   81452156.0  ...    False   False
# 4  [United States of America]   1995-02-10   76578911.0  ...    False   False
#
#   Animation Foreign  Music  History    War  Western  TV Movie  \
# 0      True   False  False    False  False    False     False
# 1     False   False  False    False  False    False     False
# 2     False   False  False    False  False    False     False
# 3     False   False  False    False  False    False     False
# 4     False   False  False    False  False    False     False
#
#    production_country_iso
# 0                    [US]
# 1                    [US]
# 2                    [US]
# 3                    [US]
# 4                    [US]
#
# [5 rows x 38 columns]

# %%
spoken_language_df.head()
# Out:
#                                     spoken_languages
# 0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           [{'iso_639_1': 'en', 'name': 'English'}]
# 3           [{'iso_639_1': 'en', 'name': 'English'}]
# 4           [{'iso_639_1': 'en', 'name': 'English'}]

# %%
spoken_language_df['spoken_languages'][0]
# Out:
# "[{'iso_639_1': 'en', 'name': 'English'}]"

# %%
spoken_languages_lists = str_to_list_of_dicts(df = spoken_language_df, column_name = 'spoken_languages').map(genres_cleaner)
spoken_languages_lists
# Out:
# 0                  [English]
# 1        [English, Français]
# 2                  [English]
# 3                  [English]
# 4                  [English]
#                 ...
# 45461                [فارسی]
# 45462                     []
# 45463              [English]
# 45464                     []
# 45465              [English]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
spoken_language_df['language_iso'] = str_to_list_of_dicts(df = spoken_language_df, column_name = 'spoken_languages').map(language_cleaner)

# %%
spoken_language_df['spoken_languages'] = spoken_languages_lists

# %%
spoken_language_df
# Out:
#           spoken_languages language_iso
# 0                [English]         [en]
# 1      [English, Français]     [en, fr]
# 2                [English]         [en]
# 3                [English]         [en]
# 4                [English]         [en]
# ...                    ...          ...
# 45461              [فارسی]         [fa]
# 45462                   []         [tl]
# 45463            [English]         [en]
# 45464                   []           []
# 45465            [English]         [en]
#
# [45466 rows x 2 columns]

# %%
movies_meta['spoken_languages'] = spoken_languages_lists
movies_meta['language_iso'] = spoken_language_df['language_iso']
movies_meta.head()
# Out:
#    adult    budget                        genres     id    imdb_id  \
# 0  False  30000000   [Animation, Comedy, Family]    862  tt0114709
# 1  False  65000000  [Adventure, Fantasy, Family]   8844  tt0113497
# 2  False         0             [Romance, Comedy]  15602  tt0113228
# 3  False  16000000      [Comedy, Drama, Romance]  31357  tt0114885
# 4  False         0                      [Comedy]  11862  tt0113041
#
#   original_language                               production_companies  \
# 0                en                          [Pixar Animation Studios]
# 1                en  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                en                     [Warner Bros., Lancaster Gate]
# 3                en           [Twentieth Century Fox Film Corporation]
# 4                en       [Sandollar Productions, Touchstone Pictures]
#
#          production_countries release_date      revenue  ...  Fantasy  \
# 0  [United States of America]   1995-10-30  373554033.0  ...    False
# 1  [United States of America]   1995-12-15  262797249.0  ...     True
# 2  [United States of America]   1995-12-22          0.0  ...    False
# 3  [United States of America]   1995-12-22   81452156.0  ...    False
# 4  [United States of America]   1995-02-10   76578911.0  ...    False
#
#   Animation Foreign  Music History    War  Western  TV Movie  \
# 0      True   False  False   False  False    False     False
# 1     False   False  False   False  False    False     False
# 2     False   False  False   False  False    False     False
# 3     False   False  False   False  False    False     False
# 4     False   False  False   False  False    False     False
#
#    production_country_iso  language_iso
# 0                    [US]          [en]
# 1                    [US]      [en, fr]
# 2                    [US]          [en]
# 3                    [US]          [en]
# 4                    [US]          [en]
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Exploring Production Companies

# %%
company_counts = prod_companies_lists.explode().value_counts()
company_counts
# Out:
# Warner Bros.                              1250
# Metro-Goldwyn-Mayer (MGM)                 1076
# Paramount Pictures                        1003
# Twentieth Century Fox Film Corporation     836
# Universal Pictures                         830
#                                           ...
# Granox Productions                           1
# MVL Incredible Productions                   1
# Neil Breen Films                             1
# The Body                                     1
# Griffin & Phoenix Productions                1
# Name: production_companies, Length: 23537, dtype: int64

# %%
company_counts_df = company_counts.to_frame('counts').reset_index()
company_counts_df = company_counts_df.rename(columns = {'index': 'production_company'})
company_counts_df
# Out:
#                            production_company  counts
# 0                                Warner Bros.    1250
# 1                   Metro-Goldwyn-Mayer (MGM)    1076
# 2                          Paramount Pictures    1003
# 3      Twentieth Century Fox Film Corporation     836
# 4                          Universal Pictures     830
# ...                                       ...     ...
# 23532                      Granox Productions       1
# 23533              MVL Incredible Productions       1
# 23534                        Neil Breen Films       1
# 23535                                The Body       1
# 23536           Griffin & Phoenix Productions       1
#
# [23537 rows x 2 columns]

# %%
company_counts_df = company_counts_df[company_counts_df.counts > 130]
company_counts_df
# Out:
#                              production_company  counts
# 0                                  Warner Bros.    1250
# 1                     Metro-Goldwyn-Mayer (MGM)    1076
# 2                            Paramount Pictures    1003
# 3        Twentieth Century Fox Film Corporation     836
# 4                            Universal Pictures     830
# 5                 Columbia Pictures Corporation     448
# 6                                        Canal+     438
# 7                             Columbia Pictures     431
# 8                            RKO Radio Pictures     290
# 9                                United Artists     279
# 10                              New Line Cinema     277
# 11                         Walt Disney Pictures     263
# 12                          Touchstone Pictures     225
# 13                             TriStar Pictures     197
# 14                                      Mosfilm     188
# 15                                Miramax Films     183
# 16                              France 2 Cinéma     168
# 17  Centre National de la Cinématographie (CNC)     163
# 18                                 Toho Company     142
# 19                                    BBC Films     131

# %%
def counts_horizontal_bar(df, x_column, y_column, x_min, x_max, x_inc, ax):
    x_data = df[x_column]
    y_data = df[y_column]
    y = np.arange(len(y_data))
    x = np.linspace(x_min, x_max, (x_max-x_min)//x_inc + 1, dtype='int')
    
    ax.barh(y_data, x_data)
    ax.invert_yaxis()
    ax.set_yticks(y)
    ax.set_xticks(x)
    ax.set_xticklabels(x, fontsize = 18, rotation = 45)
    ax.set_yticklabels(y_data, fontsize = 18)
    ax.xaxis.grid(True)
    fig.tight_layout()

fig, ax = plt.subplots(figsize=(18,10))
ax.set_xlabel('# of Movies', fontsize = 24)
ax.set_title('Counts of Movies by Production Company', fontsize = 24)

counts_horizontal_bar(company_counts_df, 'counts', 'production_company', 100, 1300, 50, ax)

# %% [markdown]
# ### Exploring Production Countries

# %%
countries_counts = prod_countries_lists.explode().value_counts()
countries_counts
# Out:
# United States of America                21153
# United Kingdom                           4094
# France                                   3940
# Germany                                  2254
# Italy                                    2169
#                                         ...
# Brunei Darussalam                           1
# Moldova                                     1
# United States Minor Outlying Islands        1
# Madagascar                                  1
# French Polynesia                            1
# Name: production_countries, Length: 160, dtype: int64

# %%
countries_counts_df = countries_counts.to_frame('counts').reset_index().rename(columns = {'index': 'production_country'})
countries_counts_df
# Out:
#                        production_country  counts
# 0                United States of America   21153
# 1                          United Kingdom    4094
# 2                                  France    3940
# 3                                 Germany    2254
# 4                                   Italy    2169
# ..                                    ...     ...
# 155                     Brunei Darussalam       1
# 156                               Moldova       1
# 157  United States Minor Outlying Islands       1
# 158                            Madagascar       1
# 159                      French Polynesia       1
#
# [160 rows x 2 columns]

# %%
countries_counts_df = countries_counts_df[countries_counts_df.counts > 320]
countries_counts_df
# Out:
#           production_country  counts
# 0   United States of America   21153
# 1             United Kingdom    4094
# 2                     France    3940
# 3                    Germany    2254
# 4                      Italy    2169
# 5                     Canada    1765
# 6                      Japan    1648
# 7                      Spain     964
# 8                     Russia     912
# 9                      India     828
# 10                 Hong Kong     596
# 11                    Sweden     588
# 12                 Australia     570
# 13               South Korea     495
# 14                   Belgium     447
# 15                   Denmark     386
# 16                   Finland     383
# 17               Netherlands     375
# 18                     China     372
# 19                    Mexico     329

# %%
fig, ax = plt.subplots(figsize=(18,10))
ax.set_xlabel('# of Movies', fontsize = 24)
ax.set_title('Counts of Movies by Production Country', fontsize = 24)

counts_horizontal_bar(countries_counts_df, 'counts', 'production_country', 300, 21200, 1100, ax)

# %%
ratings = pd.read_csv('./archive/ratings.csv')
ratings.head(2)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
ratings['movieId'] = ratings['movieId'].apply(str)
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    object
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 794.2+ MB

# %%
#movies_ratings = pd.merge(movies_meta, ratings, how='left', left_on=['id'], right_on=['movieId'])
#movies_ratings

# %%
movies_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   adult                   45466 non-null  object
#  1   budget                  45466 non-null  object
#  2   genres                  45466 non-null  object
#  3   id                      45466 non-null  object
#  4   imdb_id                 45449 non-null  object
#  5   original_language       45455 non-null  object
#  6   production_companies    45466 non-null  object
#  7   production_countries    45466 non-null  object
#  8   release_date            45379 non-null  object
#  9   revenue                 45460 non-null  float64
#  10  runtime                 45203 non-null  float64
#  11  spoken_languages        45466 non-null  object
#  12  status                  45379 non-null  object
#  13  title                   45460 non-null  object
#  14  video                   45460 non-null  object
#  15  vote_average            45460 non-null  float64
#  16  vote_count              45460 non-null  float64
#  17  Drama                   45466 non-null  bool
#  18  Comedy                  45466 non-null  bool
#  19  Thriller                45466 non-null  bool
#  20  Romance                 45466 non-null  bool
#  21  Action                  45466 non-null  bool
#  22  Horror                  45466 non-null  bool
#  23  Crime                   45466 non-null  bool
#  24  Documentary             45466 non-null  bool
#  25  Adventure               45466 non-null  bool
#  26  Science Fiction         45466 non-null  bool
#  27  Family                  45466 non-null  bool
#  28  Mystery                 45466 non-null  bool
#  29  Fantasy                 45466 non-null  bool
#  30  Animation               45466 non-null  bool
#  31  Foreign                 45466 non-null  bool
#  32  Music                   45466 non-null  bool
#  33  History                 45466 non-null  bool
#  34  War                     45466 non-null  bool
#  35  Western                 45466 non-null  bool
#  36  TV Movie                45466 non-null  bool
#  37  production_country_iso  45466 non-null  object
#  38  language_iso            45466 non-null  object
# dtypes: bool(20), float64(4), object(15)
# memory usage: 7.5+ MB

# %%
movies_meta['vote_average'].head()
# Out:
# 0    7.7
# 1    6.9
# 2    6.5
# 3    6.1
# 4    5.7
# Name: vote_average, dtype: float64

# %%
movies_meta['vote_count'].head()
# Out:
# 0    5415.0
# 1    2413.0
# 2      92.0
# 3      34.0
# 4     173.0
# Name: vote_count, dtype: float64

# %%
ratings_counts = ratings['movieId'].value_counts()
ratings_counts
# Out:
# 356       91921
# 318       91082
# 296       87901
# 593       84078
# 2571      77960
#           ...
# 149634        1
# 92906         1
# 136180        1
# 136988        1
# 138364        1
# Name: movieId, Length: 45115, dtype: int64

# %%
ratings_counts = ratings_counts.to_frame('counts').reset_index().rename(columns = {'index': 'movieId'})
ratings_counts
# Out:
#       movieId  counts
# 0         356   91921
# 1         318   91082
# 2         296   87901
# 3         593   84078
# 4        2571   77960
# ...       ...     ...
# 45110  149634       1
# 45111   92906       1
# 45112  136180       1
# 45113  136988       1
# 45114  138364       1
#
# [45115 rows x 2 columns]

# %%
ratings_counts = ratings_counts[ratings_counts.counts > 999]
ratings_counts
# Out:
#      movieId  counts
# 0        356   91921
# 1        318   91082
# 2        296   87901
# 3        593   84078
# 4       2571   77960
# ...      ...     ...
# 3742   25771    1004
# 3743    7017    1002
# 3744    5105    1000
# 3745    6650    1000
# 3746    6763    1000
#
# [3747 rows x 2 columns]

# %%
ratings_counts[ratings_counts.movieId == '356']
# Out:
#   movieId  counts
# 0     356   91921

# %%
movies_meta.head()
# Out:
#    adult    budget                        genres     id    imdb_id  \
# 0  False  30000000   [Animation, Comedy, Family]    862  tt0114709
# 1  False  65000000  [Adventure, Fantasy, Family]   8844  tt0113497
# 2  False         0             [Romance, Comedy]  15602  tt0113228
# 3  False  16000000      [Comedy, Drama, Romance]  31357  tt0114885
# 4  False         0                      [Comedy]  11862  tt0113041
#
#   original_language                               production_companies  \
# 0                en                          [Pixar Animation Studios]
# 1                en  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                en                     [Warner Bros., Lancaster Gate]
# 3                en           [Twentieth Century Fox Film Corporation]
# 4                en       [Sandollar Productions, Touchstone Pictures]
#
#          production_countries release_date      revenue  ...  Fantasy  \
# 0  [United States of America]   1995-10-30  373554033.0  ...    False
# 1  [United States of America]   1995-12-15  262797249.0  ...     True
# 2  [United States of America]   1995-12-22          0.0  ...    False
# 3  [United States of America]   1995-12-22   81452156.0  ...    False
# 4  [United States of America]   1995-02-10   76578911.0  ...    False
#
#   Animation Foreign  Music History    War  Western  TV Movie  \
# 0      True   False  False   False  False    False     False
# 1     False   False  False   False  False    False     False
# 2     False   False  False   False  False    False     False
# 3     False   False  False   False  False    False     False
# 4     False   False  False   False  False    False     False
#
#    production_country_iso  language_iso
# 0                    [US]          [en]
# 1                    [US]      [en, fr]
# 2                    [US]          [en]
# 3                    [US]          [en]
# 4                    [US]          [en]
#
# [5 rows x 39 columns]

# %%
movies_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   adult                   45466 non-null  object
#  1   budget                  45466 non-null  object
#  2   genres                  45466 non-null  object
#  3   id                      45466 non-null  object
#  4   imdb_id                 45449 non-null  object
#  5   original_language       45455 non-null  object
#  6   production_companies    45466 non-null  object
#  7   production_countries    45466 non-null  object
#  8   release_date            45379 non-null  object
#  9   revenue                 45460 non-null  float64
#  10  runtime                 45203 non-null  float64
#  11  spoken_languages        45466 non-null  object
#  12  status                  45379 non-null  object
#  13  title                   45460 non-null  object
#  14  video                   45460 non-null  object
#  15  vote_average            45460 non-null  float64
#  16  vote_count              45460 non-null  float64
#  17  Drama                   45466 non-null  bool
#  18  Comedy                  45466 non-null  bool
#  19  Thriller                45466 non-null  bool
#  20  Romance                 45466 non-null  bool
#  21  Action                  45466 non-null  bool
#  22  Horror                  45466 non-null  bool
#  23  Crime                   45466 non-null  bool
#  24  Documentary             45466 non-null  bool
#  25  Adventure               45466 non-null  bool
#  26  Science Fiction         45466 non-null  bool
#  27  Family                  45466 non-null  bool
#  28  Mystery                 45466 non-null  bool
#  29  Fantasy                 45466 non-null  bool
#  30  Animation               45466 non-null  bool
#  31  Foreign                 45466 non-null  bool
#  32  Music                   45466 non-null  bool
#  33  History                 45466 non-null  bool
#  34  War                     45466 non-null  bool
#  35  Western                 45466 non-null  bool
#  36  TV Movie                45466 non-null  bool
#  37  production_country_iso  45466 non-null  object
#  38  language_iso            45466 non-null  object
# dtypes: bool(20), float64(4), object(15)
# memory usage: 7.5+ MB

# %%
def budget_cleaner(string):
    if string.isnumeric():
        val = int(string)
        return val
    
    return 0

# %%
movies_meta['budget'] = movies_meta['budget'].map(budget_cleaner)
movies_meta['budget'].head()
# Out:
# 0    30000000
# 1    65000000
# 2           0
# 3    16000000
# 4           0
# Name: budget, dtype: int64
